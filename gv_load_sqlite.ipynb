# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///static/data/clean_gunvio_vol4.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['gun_vio_vol4']

# %%
engine.execute('SELECT * FROM gun_vio_vol4 LIMIT 5').fetchall()
# Out:
# [(92114, '1/1/2014', 'Kentucky', 'Lexington', 'Sixth Street and Elm Tree Lane', 'http://www.gunviolencearchive.org/incident/92114', 38.0507, -84.4829, 1, 0, 0, 0, 1, 0, 0, 0, 1, 2014),
#  (92117, '1/1/2014', 'Kentucky', 'Cynthiana', None, 'http://www.gunviolencearchive.org/incident/92117', 38.4333, -84.3542, 2, 0, 0, 0, 2, 1, 1, 0, 1, 2014),
#  (92119, '1/1/2014', 'Kentucky', 'Louisville', '38th and Broadway', 'http://www.gunviolencearchive.org/incident/92119', 38.2501, -85.815, 1, 0, 0, 0, 1, 0, 0, 0, 1, 2014),
#  (92122, '1/1/2014', 'Virginia', 'Falls Church', 'North Washington Street', 'http://www.gunviolencearchive.org/incident/92122', 38.8847, -77.1672, 0, 0, 0, 0, 0, 0, 1, 0, 0, 2014),
#  (92125, '1/1/2014', 'Oklahoma', 'Lawton', 'Sheridan and Pollard', 'http://www.gunviolencearchive.org/incident/92125', 34.6347, -98.4222, 1, 0, 0, 0, 2, 0, 2, 0, 0, 2014)]

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
inspector = inspect(engine)
gvdata_co=inspector.get_columns('gun_vio_vol4')

for column in gvdata_co:
      print(column["name"],column["type"])
# Out:
# incident_id INTEGER
# date TEXT
# state TEXT
# city_or_county TEXT
# address TEXT
# incident_url TEXT
# latitude REAL
# longitude REAL
# age_group_Adult INTEGER
# age_group_Teen INTEGER
# age_group_Child INTEGER
# Female INTEGER
# Male INTEGER
# Arrested INTEGER
# Unharmed INTEGER
# Killed INTEGER
# Injured INTEGER
# year INTEGER

# %%
gvdata=Base.classes.gun_vio_vol4
gvdata
# Out:
# sqlalchemy.ext.automap.gun_vio_vol4

# %%
gv=session.query(gvdata).all()
mylist=[]
for obj in gv:
    mydict={}
    for k,v in obj.__dict__.items():
        if k != '_sa_instance_state':
            
            mydict[k]=v
    mylist.append(mydict)
mylist
# Out:
# [{'state': 'Kentucky',
#   'address': 'Sixth Street and Elm Tree Lane',
#   'incident_url': 'http://www.gunviolencearchive.org/incident/92114',
#   'longitude': -84.4829,
#   'age_group_Teen': 0,
#   'Female': 0,
#   'Arrested': 0,
#   'Killed': 0,
#   'year': 2014,
#   'city_or_county': 'Lexington',
#   'incident_id': 92114,
#   'date': '1/1/2014',
#   'latitude': 38.0507,
#   'age_group_Adult': 1,
#   'age_group_Child': 0,
#   'Male': 1,
#   'Unharmed': 0,
#   'Injured': 1},
#  {'state': 'Kentucky',
#   'address': None,
#   'incident_url': 'http://www.gunviolencearchive.org/incident/92117',
#   'longitude': -84.3542,
#   'age_group_Teen': 0,
#   'Female': 0,
#   'Arrested': 1,
#   'Killed': 0,
#   'year': 2014,
#   'city_or_county': 'Cynthiana',
#   'incident_id': 92117,
#   'date': '1/1/2014',
#   'latitude': 38.4333,
#   'age_group_Adult': 2,
#   'age_group_Child': 0,
#   'Male': 2,
#   'Unharmed': 1,
#   'Injured': 1},
#  {'state': 'Kentucky',
# ...

# %%
gvyear=Base.classes.year_state
